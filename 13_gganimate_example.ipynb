# %% [markdown]
# ## Install `gapminder` package

# %% [markdown]
# ```sh
#
# # from a terminal
#
# mamba install -c conda-forge r-gapminder
# ```

# %% [markdown]
# ## Load libraries

# %%
library('tidyverse')
library('gganimate')
library('palmerpenguins')
library('gapminder')

# %% [markdown]
# ## Function for displaying `GIFs`

# %%
display_gif <- function(gganim, ...){
    
    raw = suppressMessages(animate(gganim, ...))
    
    contents <- base64enc::base64encode(raw)
    tag <- '<img src="data:image/gif;base64,%s">'
    
    IRdisplay::display_html(sprintf(tag, contents))
    
}

# %%
iris |> head ()
# Out:
#   Sepal.Length Sepal.Width Petal.Length Petal.Width Species
# 1 5.1          3.5         1.4          0.2         setosa
# 2 4.9          3.0         1.4          0.2         setosa
# 3 4.7          3.2         1.3          0.2         setosa
# 4 4.6          3.1         1.5          0.2         setosa
# 5 5.0          3.6         1.4          0.2         setosa
# 6 5.4          3.9         1.7          0.4         setosa

# %% [markdown]
# ## Iris example

# %%
theme_set(theme_gray(base_size = 18))

anim = ggplot(iris, aes(x = Petal.Width, y = Petal.Length, colour = Species)) + 
    geom_point(size = 4, alpha = 0.75) +
     scale_color_brewer(palette = 'Set2') +
     ggtitle('Now showing {closest_state}') +   # Closest_state to show dynamic titles
    transition_states(Species,
                      transition_length = 2,
                      state_length = 1) + 
    enter_fade() + 
    exit_shrink()

display_gif(anim, w = 600, h = 400)
# Out:
# <img src="data:image/gif;base64,...">

# %% [markdown]
# ## Tweening

# %%
penguins |> head()
# Out:
#   species island    bill_length_mm bill_depth_mm flipper_length_mm body_mass_g
# 1 Adelie  Torgersen 39.1           18.7          181               3750
# 2 Adelie  Torgersen 39.5           17.4          186               3800
# 3 Adelie  Torgersen 40.3           18.0          195               3250
# 4 Adelie  Torgersen   NA             NA           NA                 NA
# 5 Adelie  Torgersen 36.7           19.3          193               3450
# 6 Adelie  Torgersen 39.3           20.6          190               3650
#   sex    year
# 1 male   2007
# 2 female 2007
# 3 female 2007
# 4 NA     2007
# 5 female 2007
# 6 male   2007

# %%
penguins2 = penguins |> 
    mutate(penguin_id = row_number()) |>
    pivot_longer(cols = c(bill_length_mm, bill_depth_mm)) |>
    filter(species == 'Adelie') |>
    select(species, name, value, penguin_id)

penguins2 |> head()
# Out:
#   species name           value penguin_id
# 1 Adelie  bill_length_mm 39.1  1
# 2 Adelie  bill_depth_mm  18.7  1
# 3 Adelie  bill_length_mm 39.5  2
# 4 Adelie  bill_depth_mm  17.4  2
# 5 Adelie  bill_length_mm 40.3  3
# 6 Adelie  bill_depth_mm  18.0  3

# %%
p = ggplot(penguins2, aes(x = value)) + 
    geom_histogram() + 
    geom_rug()

p
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# Warning message:
# “Removed 2 rows containing non-finite values (`stat_bin()`).”
# plot without title

# %%
anim = ggplot(penguins2, aes(x = value, group = penguin_id)) + 
    geom_histogram() + 
    geom_rug() +
    transition_states(name) +
    ggtitle('{closest_state}')

display_gif(anim, w = 600, h = 400)
# Out:
# Warning message:
# “Removed 2 rows containing non-finite values (`stat_bin()`).”
# <img src="data:image/gif;base64,...">

# %% [markdown]
# ### What about body mass versus bill depth/bill length?

# %%
penguins2 |> head()
# Out:
#   species name           value penguin_id
# 1 Adelie  bill_length_mm 39.1  1
# 2 Adelie  bill_depth_mm  18.7  1
# 3 Adelie  bill_length_mm 39.5  2
# 4 Adelie  bill_depth_mm  17.4  2
# 5 Adelie  bill_length_mm 40.3  3
# 6 Adelie  bill_depth_mm  18.0  3

# %%
penguins3 = penguins |> 
    mutate(penguin_id = row_number()) |>    #Generate an ID column for each penguin
    pivot_longer(cols = c(bill_length_mm, bill_depth_mm)) #|>
    # filter(species == 'Adelie') |>
    # select(species, name, value, body_mass_g, penguin_id)

penguins3 |> head()
# Out:
#   species island    flipper_length_mm body_mass_g sex    year penguin_id
# 1 Adelie  Torgersen 181               3750        male   2007 1
# 2 Adelie  Torgersen 181               3750        male   2007 1
# 3 Adelie  Torgersen 186               3800        female 2007 2
# 4 Adelie  Torgersen 186               3800        female 2007 2
# 5 Adelie  Torgersen 195               3250        female 2007 3
# 6 Adelie  Torgersen 195               3250        female 2007 3
#   name           value
# 1 bill_length_mm 39.1
# 2 bill_depth_mm  18.7
# 3 bill_length_mm 39.5
# 4 bill_depth_mm  17.4
# 5 bill_length_mm 40.3
# 6 bill_depth_mm  18.0

# %%
anim = ggplot (penguins3, aes (x=value, y=body_mass_g, color = species, group = penguin_id)) + 
    geom_point (na.rm = T) +
    scale_color_brewer (palette = 'Set2') +
    labs (x = '{closest_state}') +
    transition_states (name) 

display_gif (anim, w = 600, h= 400)
# Out:
# <img src="data:image/gif;base64,...">

# %% [markdown]
# ## Bar chart race

# %% [markdown]
# Adapted from excellent example here: [https://evamaerey.github.io/little_flipbooks_library/racing_bars/racing_barcharts.html](https://evamaerey.github.io/little_flipbooks_library/racing_bars/racing_barcharts.html)

# %% [raw]
# ranked_countries = gapminder |>
#   select(country, pop, year, continent) |>
#   group_by(year) |>
#   arrange(year, -pop) |>
#   mutate(rank = row_number()) |>
#   filter(rank <= 10)
#
# ranked_countries |> head()

# %%
theme_set(theme_void(base_size = 20))

anim = ggplot(ranked_countries,  
              aes(xmin = 0,  
                  xmax = pop / 1000000,
                  ymin = rank - .45,  
                  ymax = rank + .45,
                  y = rank,
                  fill = continent)) +  
    geom_rect(alpha = .7) +  
    geom_text(col = "gray13",  
              hjust = "right",  
              aes(label = country), 
              size = 8,
              x = -50) + 
    geom_text(x = 1000 , y = -10,  
              family = "Monospace",  
              aes(label = as.character(year)),  
              size = 26, col = "grey40") +
    scale_fill_brewer(palette = "Dark2") +   
    scale_y_reverse() +  
    scale_x_continuous(limits = c(-600, 1400), breaks = c(0, 400, 800, 1200)) +  
    labs(x = 'Population (millions)', y = '', fill = NULL) +  
    theme_void() +
    theme(legend.text = element_text(size = 16), legend.key.size = unit(0.5, "in") ) +
    transition_time(year) + enter_fade() + exit_fade() # this is it!
    
display_gif(anim, h = 700, w = 750, duration = 30, nframes = 300)
# Out:
# Error in ggplot(ranked_countries, aes(xmin = 0, xmax = pop/1e+06, ymin = rank - : object 'ranked_countries' not found
# Traceback:
#
# 1. ggplot(ranked_countries, aes(xmin = 0, xmax = pop/1e+06, ymin = rank -
#  .     0.45, ymax = rank + 0.45, y = rank, fill = continent))

# %% [markdown]
# ### Make a bar chart for one year with `geom_col`

# %%
ranked_countries |> head()
# Out:
#   country       pop       year continent rank
# 1 China         556263527 1952 Asia      1
# 2 India         372000000 1952 Asia      2
# 3 United States 157553000 1952 Americas  3
# 4 Japan          86459025 1952 Asia      4
# 5 Indonesia      82052000 1952 Asia      5
# 6 Germany        69145952 1952 Europe    6

# %% [markdown]
# ### Make a bar chart for one year with `geom_rect`
